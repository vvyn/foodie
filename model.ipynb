# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#       --------------------------------------- 0.2/11.6 MB 5.3 MB/s eta 0:00:03
#      - -------------------------------------- 0.3/11.6 MB 3.9 MB/s eta 0:00:03
#      - -------------------------------------- 0.5/11.6 MB 3.9 MB/s eta 0:00:03
#      -- ------------------------------------- 0.6/11.6 MB 3.5 MB/s eta 0:00:04
#      -- ------------------------------------- 0.7/11.6 MB 3.2 MB/s eta 0:00:04
#      -- ------------------------------------- 0.8/11.6 MB 2.9 MB/s eta 0:00:04
#      --- ------------------------------------ 0.9/11.6 MB 2.8 MB/s eta 0:00:04
#      --- ------------------------------------ 1.1/11.6 MB 3.0 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.2/11.6 MB 2.9 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.3/11.6 MB 2.9 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/11.6 MB 2.9 MB/s eta 0:00:04
# ...

# %%
import os
import pandas as pd

# %%
data_foods_csv_path = '/data/foods.csv'
data_ratings_csv_path = '/data/ratings.csv'

data_foods = pd.read_csv(data_foods_csv_path)
data_ratings = pd.read_csv(data_ratings_csv_path)

print(data_foods.head)
print(data_ratings.head)
# Out:
# Running cells with 'chatbot-env (Python 3.12.3)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/vicav/Projects/nlp-project/chatbot-env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
